# %% [markdown]
# # Perturbation-based: SHAP (KernelSHAP)

# %%
# Bootstrap project path
import sys, os
from pathlib import Path

ROOT = Path.cwd()
# Walk up until we find the 'code' folder
while not (ROOT / "code").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.append(str((ROOT / "code").resolve()))

# %%
from utils.seed import set_seed
from plots.perturbation_plots import run_shap_plot

set_seed(42)
out_path = run_shap_plot(
    model_name="random_forest",
    dataset="breast_cancer",
    chapter="02_perturbation_based",
    output_prefix="shap_kernel_summary",
    max_display=10,
)
print(f"Saved SHAP summary plot to: {out_path}")
# Out:
#   0%|          | 0/114 [00:00<?, ?it/s]
# /Users/juliawenkmann/Documents/CodingProjects/xai_lecture_notes/code/explainers/shap_explainer.py:30: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(sv, X_test, show=False, max_display=max_display)
# /Users/juliawenkmann/miniconda3/envs/ml/lib/python3.11/site-packages/shap/plots/_beeswarm.py:726: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# ...
