# %% [markdown]
# # LIME — Perturbation-based
# This short notebook delegates all logic to the `code/` package and saves a figure to `figures/01_perturbation_based`.

# %%
# Ensure project root is on sys.path
from pathlib import Path
import sys
NB_DIR = Path.cwd()
ROOT = NB_DIR.parents[1]  # project root
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

CHAPTER = "01_perturbation_based"

# %%
# Imports from our clean codebase
from code.data.datasets import load_synthetic_classification
from code.models.toy_logistic import train_toy_logistic
from code.explainers.perturbation import explain_with_lime
from code.plots.io import save_fig
from code.utils.paths import figures_chapter_dir
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Imports from our clean codebase
# ----> 2 from code.data.datasets import load_synthetic_classification
#       3 from code.models.toy_logistic import train_toy_logistic
#       4 from code.explainers.perturbation import explain_with_lime
#
# ModuleNotFoundError: No module named 'code.data'; 'code' is not a package

# %%
# Data + model
X_train, y_train, X_test, y_test, feature_names, class_names = load_synthetic_classification()
model = train_toy_logistic(X_train, y_train)

# %%
# Explain a single instance with LIME and save the figure
instance = X_test[0]
fig = explain_with_lime(model, X_train, feature_names, class_names, instance, num_features=8)
outpath = figures_chapter_dir(CHAPTER) / "lime_example.png"
save_fig(fig, outpath)
print(f"Saved: {outpath}")
