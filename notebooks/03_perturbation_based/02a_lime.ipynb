# %% [markdown]
# # Perturbation-based: LIME

# %%
# Bootstrap project path
import sys, os
from pathlib import Path

ROOT = Path.cwd()
# Walk up until we find the 'code' folder
while not (ROOT / "code").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.append(str((ROOT / "code").resolve()))

# %%
from utils.seed import set_seed
from plots.perturbation_plots import run_lime_plot

set_seed(42)
out_path = run_lime_plot(
    model_name="random_forest",
    dataset="breast_cancer",
    chapter="02_perturbation_based",
    output_prefix="lime_example",
    sample_index=0,
)
print(f"Saved LIME plot to: {out_path}")
# Out:
# /Users/juliawenkmann/miniconda3/envs/ml/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Saved LIME plot to: /Users/juliawenkmann/Documents/CodingProjects/xai_lecture_notes/figures/02_perturbation_based/lime_example.png
