# %% [markdown]
# # Perturbation-based: SHAP for Time Series (lag features)

# %%
# Make 'code/' importable as top-level (Option B)
import sys
from pathlib import Path
ROOT = Path.cwd()
while not (ROOT / "code").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str((ROOT / "code").resolve()))

# %%
from utils.seed import set_seed
from plots.perturbation_plots import run_shap_timeseries_plot

set_seed(42)
out_path = run_shap_timeseries_plot(
    dataset="sunspots",
    n_lags=12,
    chapter="02_perturbation_based",
    output_prefix="shap_ts_summary"
)
print(f"Saved SHAP TS plot to: {out_path}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 5
#       2 from plots.perturbation_plots import run_shap_timeseries_plot
#       4 set_seed(42)
# ----> 5 out_path = run_shap_timeseries_plot(
#       6     dataset="sunspots",
#       7     n_lags=12,
#       8     chapter="02_perturbation_based",
#       9     output_prefix="shap_ts_summary"
#      10 )
#      11 print(f"Saved SHAP TS plot to: {out_path}")
#
# File ~/Documents/CodingProjects/xai_lecture_notes/code/plots/perturbation_plots.py:45, in run_shap_timeseries_plot(dataset, n_lags, chapter, output_prefix)
#      42 X_train, X_test = X_df.iloc[:split], X_df.iloc[split:]
#      43 y_train, y_test = y.iloc[:split], y.iloc[split:]
# ---> 45 model = get_model("ridge")  # regression
#      46 model.fit(X_train, y_train)
# ...
